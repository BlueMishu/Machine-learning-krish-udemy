# %%
import logging

# %%
import logging

# configure the basic logging setting

logging.basicConfig(level=logging.DEBUG)


# log messeges with different severity messege
logging.debug("This is a debug messege")
logging.info("This is an info messege")
logging.warning("This is a warning messege")
logging.error("This is a error messege")
logging.critical("This is a critical messege")
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 464, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 460, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'messege'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 706, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 675, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 466, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'messege'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 618, in run_forever
#     self._run_once()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 1951, in _run_once
#     handle._run()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/d8/f71p2q8s2m333vv2_ntg7vs40000gn/T/ipykernel_94914/76344934.py", line 9, in <module>
#     logging.debug("This is a debug messege")
# Message: 'This is a debug messege'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 464, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 460, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'messege'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 706, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 675, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 466, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'messege'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 618, in run_forever
#     self._run_once()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 1951, in _run_once
#     handle._run()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/d8/f71p2q8s2m333vv2_ntg7vs40000gn/T/ipykernel_94914/76344934.py", line 10, in <module>
#     logging.info("This is an info messege")
# Message: 'This is an info messege'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 464, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 460, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'messege'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 706, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 675, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 466, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'messege'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 618, in run_forever
#     self._run_once()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 1951, in _run_once
#     handle._run()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/d8/f71p2q8s2m333vv2_ntg7vs40000gn/T/ipykernel_94914/76344934.py", line 11, in <module>
#     logging.warning("This is a warning messege")
# Message: 'This is a warning messege'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 464, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 460, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'messege'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 706, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 675, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 466, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'messege'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 618, in run_forever
#     self._run_once()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 1951, in _run_once
#     handle._run()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/d8/f71p2q8s2m333vv2_ntg7vs40000gn/T/ipykernel_94914/76344934.py", line 12, in <module>
#     logging.error("This is a error messege")
# Message: 'This is a error messege'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 464, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 460, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'messege'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 706, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 675, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 466, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'messege'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 618, in run_forever
#     self._run_once()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 1951, in _run_once
#     handle._run()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/d8/f71p2q8s2m333vv2_ntg7vs40000gn/T/ipykernel_94914/76344934.py", line 13, in <module>
#     logging.critical("This is a critical messege")
# Message: 'This is a critical messege'
# Arguments: ()

# %%
import logging

# configure logging
logging.basicConfig(
    filename='app.log',
    filemode='w',
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

# log messeges with different severity messege
logging.debug("This is a debug messege")
logging.info("This is an info messege")
logging.warning("This is a warning messege")
logging.error("This is a error messege")
logging.critical("This is a critical messege")
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 464, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 460, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'messege'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 706, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 675, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 466, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'messege'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 618, in run_forever
#     self._run_once()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 1951, in _run_once
#     handle._run()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/d8/f71p2q8s2m333vv2_ntg7vs40000gn/T/ipykernel_94914/2854707094.py", line 13, in <module>
#     logging.debug("This is a debug messege")
# Message: 'This is a debug messege'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 464, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 460, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'messege'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 706, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 675, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 466, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'messege'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 618, in run_forever
#     self._run_once()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 1951, in _run_once
#     handle._run()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/d8/f71p2q8s2m333vv2_ntg7vs40000gn/T/ipykernel_94914/2854707094.py", line 14, in <module>
#     logging.info("This is an info messege")
# Message: 'This is an info messege'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 464, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 460, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'messege'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 706, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 675, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 466, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'messege'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 618, in run_forever
#     self._run_once()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 1951, in _run_once
#     handle._run()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/d8/f71p2q8s2m333vv2_ntg7vs40000gn/T/ipykernel_94914/2854707094.py", line 15, in <module>
#     logging.warning("This is a warning messege")
# Message: 'This is a warning messege'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 464, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 460, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'messege'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 706, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 675, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 466, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'messege'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 618, in run_forever
#     self._run_once()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 1951, in _run_once
#     handle._run()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/d8/f71p2q8s2m333vv2_ntg7vs40000gn/T/ipykernel_94914/2854707094.py", line 16, in <module>
#     logging.error("This is a error messege")
# Message: 'This is a error messege'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 464, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 460, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'messege'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 706, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 675, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/logging/__init__.py", line 466, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'messege'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 618, in run_forever
#     self._run_once()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/base_events.py", line 1951, in _run_once
#     handle._run()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/bluemishu/Coding/ML/python/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/d8/f71p2q8s2m333vv2_ntg7vs40000gn/T/ipykernel_94914/2854707094.py", line 17, in <module>
#     logging.critical("This is a critical messege")
# Message: 'This is a critical messege'
# Arguments: ()
