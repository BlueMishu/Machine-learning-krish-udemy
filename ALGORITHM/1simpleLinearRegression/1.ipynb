# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#       3 import numpy as np
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
conda install matplotlib
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/bluemishu/venv
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     contourpy-1.3.1            |  py310h48ca7d4_0         249 KB
#     fonttools-4.51.0           |  py310h80987f9_0         2.4 MB
#     freetype-2.12.1            |       hadb7bae_2         582 KB  conda-forge
#     kiwisolver-1.4.4           |  py310h313beb8_0          61 KB
#     lcms2-2.16                 |       ha0e7c42_0         207 KB  conda-forge
#     lerc-4.0.0                 |       h9a09cb3_0         211 KB  conda-forge
#     libdeflate-1.22            |       hd74edd7_0          53 KB  conda-forge
#     libjpeg-turbo-3.0.3        |       h80987f9_0         577 KB
#     libpng-1.6.44              |       hc14010f_0         257 KB  conda-forge
#     libtiff-4.7.0              |       hfce79cd_1         358 KB  conda-forge
#     libwebp-base-1.4.0         |       h93a5062_0         281 KB  conda-forge
#     libxcb-1.17.0              |       hdb1d25a_0         316 KB  conda-forge
#     matplotlib-3.9.2           |  py310hca03da5_1           8 KB
#     matplotlib-base-3.9.2      |  py310h7ef442a_1         7.0 MB
#     numpy-2.1.3                |  py310h3b2db8e_0          12 KB
#     numpy-base-2.1.3           |  py310ha9811e2_0         6.1 MB
#     pillow-11.0.0              |  py310h530beaf_0        40.0 MB  conda-forge
#     pthread-stubs-0.3          |       h1a28f6b_1           7 KB
#     pyparsing-3.2.0            |  py310hca03da5_0         424 KB
#     unicodedata2-15.1.0        |  py310h80987f9_0         533 KB
#     xorg-libxau-1.0.11         |       hd74edd7_1          13 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hd74edd7_0          18 KB  conda-forge
#     zstd-1.5.6                 |       hb46c0d2_0         396 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        59.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/osx-arm64::blas-1.0-openblas
#   brotli             pkgs/main/osx-arm64::brotli-1.0.9-h80987f9_8
#   brotli-bin         pkgs/main/osx-arm64::brotli-bin-1.0.9-h80987f9_8
#   contourpy          pkgs/main/osx-arm64::contourpy-1.3.1-py310h48ca7d4_0
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   fonttools          pkgs/main/osx-arm64::fonttools-4.51.0-py310h80987f9_0
#   freetype           conda-forge/osx-arm64::freetype-2.12.1-hadb7bae_2
#   kiwisolver         pkgs/main/osx-arm64::kiwisolver-1.4.4-py310h313beb8_0
#   lcms2              conda-forge/osx-arm64::lcms2-2.16-ha0e7c42_0
#   lerc               conda-forge/osx-arm64::lerc-4.0.0-h9a09cb3_0
#   libbrotlicommon    pkgs/main/osx-arm64::libbrotlicommon-1.0.9-h80987f9_8
#   libbrotlidec       pkgs/main/osx-arm64::libbrotlidec-1.0.9-h80987f9_8
#   libbrotlienc       pkgs/main/osx-arm64::libbrotlienc-1.0.9-h80987f9_8
#   libdeflate         conda-forge/osx-arm64::libdeflate-1.22-hd74edd7_0
#   libgfortran        pkgs/main/osx-arm64::libgfortran-5.0.0-11_3_0_hca03da5_28
#   libgfortran5       pkgs/main/osx-arm64::libgfortran5-11.3.0-h009349e_28
#   libjpeg-turbo      pkgs/main/osx-arm64::libjpeg-turbo-3.0.3-h80987f9_0
#   libopenblas        pkgs/main/osx-arm64::libopenblas-0.3.21-h269037a_0
#   libpng             conda-forge/osx-arm64::libpng-1.6.44-hc14010f_0
#   libtiff            conda-forge/osx-arm64::libtiff-4.7.0-hfce79cd_1
#   libwebp-base       conda-forge/osx-arm64::libwebp-base-1.4.0-h93a5062_0
#   libxcb             conda-forge/osx-arm64::libxcb-1.17.0-hdb1d25a_0
#   llvm-openmp        pkgs/main/osx-arm64::llvm-openmp-14.0.6-hc6e5704_0
#   matplotlib         pkgs/main/osx-arm64::matplotlib-3.9.2-py310hca03da5_1
#   matplotlib-base    pkgs/main/osx-arm64::matplotlib-base-3.9.2-py310h7ef442a_1
#   numpy              pkgs/main/osx-arm64::numpy-2.1.3-py310h3b2db8e_0
#   numpy-base         pkgs/main/osx-arm64::numpy-base-2.1.3-py310ha9811e2_0
#   openjpeg           pkgs/main/osx-arm64::openjpeg-2.5.2-h54b8e55_0
#   pillow             conda-forge/osx-arm64::pillow-11.0.0-py310h530beaf_0
#   pthread-stubs      pkgs/main/osx-arm64::pthread-stubs-0.3-h1a28f6b_1
#   pyparsing          pkgs/main/osx-arm64::pyparsing-3.2.0-py310hca03da5_0
#   unicodedata2       pkgs/main/osx-arm64::unicodedata2-15.1.0-py310h80987f9_0
#   xorg-libxau        conda-forge/osx-arm64::xorg-libxau-1.0.11-hd74edd7_1
#   xorg-libxdmcp      conda-forge/osx-arm64::xorg-libxdmcp-1.1.5-hd74edd7_0
#   zstd               conda-forge/osx-arm64::zstd-1.5.6-hb46c0d2_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2024.8.3~ --> pkgs/main::ca-certificates-2024.9.24-hca03da5_0
#
#
#
# Downloading and Extracting Packages:
# pillow-11.0.0        | 40.0 MB   |                                       |   0%
# matplotlib-base-3.9. | 7.0 MB    |                                       |   0%
#
# numpy-base-2.1.3     | 6.1 MB    |                                       |   0%
#
#
# fonttools-4.51.0     | 2.4 MB    |                                       |   0%
#
#
#
# freetype-2.12.1      | 582 KB    |                                       |   0%
#
#
#
#
# libjpeg-turbo-3.0.3  | 577 KB    |                                       |   0%
#
#
#
#
#
# unicodedata2-15.1.0  | 533 KB    |                                       |   0%
#
#
#
#
#
#
# pyparsing-3.2.0      | 424 KB    |                                       |   0%
#
#
#
#
#
#
#
# zstd-1.5.6           | 396 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 358 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 316 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.4.0   | 281 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.44        | 257 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 249 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 211 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 207 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.4     | 61 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 53 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxdmcp-1.1.5  | 18 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxau-1.0.11   | 13 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-2.1.3          | 12 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.9.2     | 8 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pthread-stubs-0.3    | 7 KB      |                                       |   0%
#
# numpy-base-2.1.3     | 6.1 MB    |                                       |   0%
#
#
# pillow-11.0.0        | 40.0 MB   |                                       |   0%
#
#
#
# freetype-2.12.1      | 582 KB    | #                                     |   3%
#
# numpy-base-2.1.3     | 6.1 MB    | #4                                    |   4%
#
#
# pillow-11.0.0        | 40.0 MB   | 2                                     |   1%
#
#
#
# freetype-2.12.1      | 582 KB    | ###############2                      |  41%
#
# pillow-11.0.0        | 40.0 MB   | 6                                     |   2%
#
#
# fonttools-4.51.0     | 2.4 MB    | #########7                            |  26%
#
#
#
# freetype-2.12.1      | 582 KB    | ##################################### | 100%
#
#
#
# pillow-11.0.0        | 40.0 MB   | 8                                     |   2%
#
#
# fonttools-4.51.0     | 2.4 MB    | #############8                        |  38%
#
# numpy-base-2.1.3     | 6.1 MB    | #####1                                |  14%
#
# numpy-base-2.1.3     | 6.1 MB    | #######1                              |  19%
#
#
# pillow-11.0.0        | 40.0 MB   | #1                                    |   3%
#
#
# pillow-11.0.0        | 40.0 MB   | #5                                    |   4%
# matplotlib-base-3.9. | 7.0 MB    |                                       |   0%
#
#
# fonttools-4.51.0     | 2.4 MB    | ###############################4      |  85%
#
# pillow-11.0.0        | 40.0 MB   | #7                                    |   5%
#
#
#
#
# libjpeg-turbo-3.0.3  | 577 KB    | #                                     |   3%
# matplotlib-base-3.9. | 7.0 MB    | 1                                     |   0%
#
# numpy-base-2.1.3     | 6.1 MB    | ###########2                          |  30%
#
#
# pillow-11.0.0        | 40.0 MB   | ##                                    |   6%
#
#
#
#
# libjpeg-turbo-3.0.3  | 577 KB    | ########2                             |  22%
# matplotlib-base-3.9. | 7.0 MB    | 8                                     |   2%
#
# pillow-11.0.0        | 40.0 MB   | ##3                                   |   6%
#
#
# fonttools-4.51.0     | 2.4 MB    | ##################################### | 100%
# matplotlib-base-3.9. | 7.0 MB    | #4                                    |   4%
#
#
#
#
# libjpeg-turbo-3.0.3  | 577 KB    | #########################6            |  69%
#
# pillow-11.0.0        | 40.0 MB   | ##5                                   |   7%
#
#
#
#
# libjpeg-turbo-3.0.3  | 577 KB    | ##################################### | 100%
#
# numpy-base-2.1.3     | 6.1 MB    | #################6                    |  48%
# pillow-11.0.0        | 40.0 MB   | ##9                                   |   8%
#
# numpy-base-2.1.3     | 6.1 MB    | ####################                  |  54%
# pillow-11.0.0        | 40.0 MB   | ###3                                  |   9%
#
# numpy-base-2.1.3     | 6.1 MB    | ######################6               |  61%
# pillow-11.0.0        | 40.0 MB   | ###6                                  |  10%
#
# numpy-base-2.1.3     | 6.1 MB    | #########################2            |  68%
# pillow-11.0.0        | 40.0 MB   | ####                                  |  11%
#
# numpy-base-2.1.3     | 6.1 MB    | ###########################6          |  75%
#
#
#
#
#
# unicodedata2-15.1.0  | 533 KB    | #1                                    |   3%
# pillow-11.0.0        | 40.0 MB   | ####3                                 |  12%
#
# numpy-base-2.1.3     | 6.1 MB    | ##############################        |  81%
# pillow-11.0.0        | 40.0 MB   | ####8                                 |  13%
#
#
#
#
#
#
# pyparsing-3.2.0      | 424 KB    | #3                                    |   4%
# matplotlib-base-3.9. | 7.0 MB    | #############                         |  35%
#
# numpy-base-2.1.3     | 6.1 MB    | ################################3     |  87%
#
#
#
#
#
# pillow-11.0.0        | 40.0 MB   | #####2                                |  14%
#
# numpy-base-2.1.3     | 6.1 MB    | ###################################7  |  97%
#
#
#
#
#
# pillow-11.0.0        | 40.0 MB   | #####6                                |  15%
#
#
#
#
#
#
# pyparsing-3.2.0      | 424 KB    | ######9                               |  19%
# matplotlib-base-3.9. | 7.0 MB    | ##############9                       |  40%
#
#
#
#
#
# pillow-11.0.0        | 40.0 MB   | #####9                                |  16%
#
#
#
#
#
#
# pyparsing-3.2.0      | 424 KB    | ############5                         |  34%
# pillow-11.0.0        | 40.0 MB   | ######4                               |  17%
#
#
#
#
#
# unicodedata2-15.1.0  | 533 KB    | ##########################6           |  72%
#
#
#
#
#
#
# pillow-11.0.0        | 40.0 MB   | ######8                               |  19%
#
#
#
#
#
# unicodedata2-15.1.0  | 533 KB    | ##################################### | 100%
# matplotlib-base-3.9. | 7.0 MB    | ####################2                 |  55%
#
#
#
#
#
#
# pyparsing-3.2.0      | 424 KB    | ##################################### | 100%
#
#
#
#
#
#
# pillow-11.0.0        | 40.0 MB   | #######2                              |  20%
#
# numpy-base-2.1.3     | 6.1 MB    | ##################################### | 100%
# matplotlib-base-3.9. | 7.0 MB    | #######################5              |  64%
#
#
#
#
#
#
#
#
#
# pillow-11.0.0        | 40.0 MB   | #######8                              |  21%
#
#
#
#
#
#
#
# zstd-1.5.6           | 396 KB    | #4                                    |   4%
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 316 KB    | ##################################### | 100%
# pillow-11.0.0        | 40.0 MB   | ########2                             |  22%
# matplotlib-base-3.9. | 7.0 MB    | ############################          |  76%
#
#
#
#
#
#
#
# zstd-1.5.6           | 396 KB    | ###########9                          |  32%
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.4.0   | 281 KB    | ##1                                   |   6%
#
#
#
#
#
#
#
#
# pillow-11.0.0        | 40.0 MB   | ########7                             |  24%
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.4.0   | 281 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# zstd-1.5.6           | 396 KB    | ##################################4   |  93%
# matplotlib-base-3.9. | 7.0 MB    | ##############################1       |  82%
#
#
#
#
#
#
#
# pillow-11.0.0        | 40.0 MB   | #########2                            |  25%
# matplotlib-base-3.9. | 7.0 MB    | ################################8     |  89%
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 358 KB    | #############2                        |  36%
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.44        | 257 KB    | ##3                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.0.0        | 40.0 MB   | #########6                            |  26%
# matplotlib-base-3.9. | 7.0 MB    | ###################################1  |  95%
#
#
#
#
#
#
#
#
# pillow-11.0.0        | 40.0 MB   | ##########                            |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 211 KB    | ##8                                   |   8%
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 358 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 211 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.4     | 61 KB     | #########7                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.0.0        | 40.0 MB   | ##########6                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 53 KB     | ###########2                          |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxdmcp-1.1.5  | 18 KB     | ################################7     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxdmcp-1.1.5  | 18 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.0.0        | 40.0 MB   | ###########1                          |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-2.1.3          | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxau-1.0.11   | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 249 KB    | ##3                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxau-1.0.11   | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-2.1.3          | 12 KB     | ##################################### | 100%
# matplotlib-base-3.9. | 7.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.0.0        | 40.0 MB   | ###########6                          |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pthread-stubs-0.3    | 7 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.0.0        | 40.0 MB   | ############2                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 249 KB    | ###########8                          |  32%
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.0.0        | 40.0 MB   | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.9.2     | 8 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.9.2     | 8 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 249 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
# %matplotlib inline

# %%
df=pd.read_csv('height-weight.csv')

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
# scatter plot
plt.scatter(df['Weight'],df['Height'])

# %%
dp.corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 dp.corr()
#
# NameError: name 'dp' is not defined

# %%
df.corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.931142
# Height  0.931142  1.000000

# %%
# seaborn for visualization
import seaborn as sns
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 2
#       1 # seaborn for visualization
# ----> 2 import seaborn as sns
#       3 sns.pairplot(df)
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/bluemishu/venv/lib/python3.10/site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: pandas>=1.2 in /Users/bluemishu/venv/lib/python3.10/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/bluemishu/venv/lib/python3.10/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/bluemishu/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/bluemishu/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/bluemishu/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/bluemishu/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/bluemishu/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/bluemishu/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/bluemishu/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/bluemishu/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/bluemishu/venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/bluemishu/venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/bluemishu/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# seaborn for visualization
import seaborn as sns
sns.pairplot(df)

# %%
# independent and dependent features

df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
x=df['Height']
print(type(x))
print(type(df))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
x
# Out:
# 0     120
# 1     135
# 2     123
# 3     145
# 4     160
# 5     162
# 6     163
# 7     175
# 8     182
# 9     170
# 10    176
# 11    182
# 12    175
# 13    183
# 14    170
# 15    177
# 16    140
# 17    159
# 18    150
# 19    167
# 20    129
# 21    140
# 22    160
# Name: Height, dtype: int64

# %%
np.array(x).shape
# Out:
# (23,)

# %%
x=df[['Weight']]
np.array(x).shape
# Out:
# (23, 1)

# %%
# independent featuere -> it should be data frame or 2d array
x=df[['Weight']]

# dependent feature -> it should be in series or 1d array
y=df['Height']

# %%
y
# Out:
#     Height
# 0      120
# 1      135
# 2      123
# 3      145
# 4      160
# 5      162
# 6      163
# 7      175
# 8      182
# 9      170
# 10     176
# 11     182
# 12     175
# 13     183
# 14     170
# 15     177
# 16     140
# 17     159
# 18     150
# 19     167
# 20     129
# 21     140
# 22     160

# %%
# train test split 

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 3
#       1 # train test split
# ----> 3 from sklearn.model_selection import train_test_split
#       4 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Note: you may need to restart the kernel to use updated packages.

# %%
# train test split 

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 3
#       1 # train test split
# ----> 3 from sklearn.model_selection import train_test_split
#       4 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
pip install scikit
# Out:
# ERROR: Could not find a version that satisfies the requirement scikit (from versions: none)
# ERROR: No matching distribution found for scikit
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn

# %%
# train test split 

from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[37], line 3
#       1 # train test split
# ----> 3 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.5.2-cp310-cp310-macosx_12_0_arm64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19.5 in /Users/bluemishu/venv/lib/python3.10/site-packages (from scikit-learn) (2.1.1)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Using cached scipy-1.14.1-cp310-cp310-macosx_14_0_arm64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.5.2-cp310-cp310-macosx_12_0_arm64.whl (11.0 MB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached scipy-1.14.1-cp310-cp310-macosx_14_0_arm64.whl (23.1 MB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.5.2 scipy-1.14.1 threadpoolctl-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# train test split 

from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train.shape
# Out:
# (17, 1)

# %%
y_train.shape
# Out:
# (17, 1)

# %%
x.shape
# Out:
# (23, 1)

# %%
x_test.shape
# Out:
# (6, 1)

# %%
# standardization
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.33497168],
#        [ 0.33497168],
#        [-1.6641678 ],
#        [ 1.36483141],
#        [-0.45256812],
#        [ 1.97063125]])

# %%
## apply linear regression

from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression(n_jobs=-1)

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
regression
# Out:
# LinearRegression(n_jobs=-1)

# %%
print("coefficient and slope :" ,regression.coef_)
# Out:
# coefficient and slope : [[17.2982057]]

# %%
print("Intercept :" ,regression.intercept_)
# Out:
# Intercept : [156.47058824]

# %%
# plot the training data with best fit line

plt.scatter(x_train,y_train)
plt.plot(x_train,regression.predict(x_train))

# %% [markdown]
# # prediction for test data
# y_pred=intercept(156.47058824) + slope(17.2982057)*x_test

# %%
# prediction for test data 

y_pred=regression.predict(x_test)

# %%
y_pred
# Out:
# array([[162.26499721],
#        [162.26499721],
#        [127.68347133],
#        [180.07972266],
#        [148.64197186],
#        [190.55897293]])

# %%
# performance matrix
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 114.84069295228699
# 9.66512588679501
# 10.716374991212605

# %% [markdown]
# # R square
# R^2=1-ssr/sst
# R^2-> coefficient of determination
# ssr-> sum of squares
# sst -> total sum of squares

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.7360826717981276

# %%
# display adjusted r square

1-(1-score)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
# Out:
# 0.6701033397476595

# %%
# OLS Linear Regression
import statsmodels.api as sm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[80], line 2
#       1 # OLS Linear Regression
# ----> 2 import statsmodels.api as sm
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in /Users/bluemishu/venv/lib/python3.10/site-packages (from statsmodels) (2.1.1)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /Users/bluemishu/venv/lib/python3.10/site-packages (from statsmodels) (1.14.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /Users/bluemishu/venv/lib/python3.10/site-packages (from statsmodels) (2.2.2)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=21.3 in /Users/bluemishu/venv/lib/python3.10/site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/bluemishu/venv/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/bluemishu/venv/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/bluemishu/venv/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/bluemishu/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.16.0)
# Downloading statsmodels-0.14.4-cp310-cp310-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 10.2 MB/s eta 0:00:00a 0:00:01
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-1.0.1 statsmodels-0.14.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# OLS Linear Regression
import statsmodels.api as sm

# %%
model=sm.OLS(y_train,x_train).fit()

# %%
prediction=model.predict(x_test)
print(prediction)
# Out:
# [  5.79440897   5.79440897 -28.78711691  23.60913442  -7.82861638
#   34.08838469]

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                 Height   R-squared (uncentered):                   0.012
# Model:                            OLS   Adj. R-squared (uncentered):             -0.050
# Method:                 Least Squares   F-statistic:                             0.1953
# Date:                Sun, 01 Dec 2024   Prob (F-statistic):                       0.664
# Time:                        17:04:34   Log-Likelihood:                         -110.03
# No. Observations:                  17   AIC:                                      222.1
# Df Residuals:                      16   BIC:                                      222.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            17.2982     39.138      0.442      0.664     -65.671     100.267
# ==============================================================================
# Omnibus:                        0.135   Durbin-Watson:                   0.002
# Prob(Omnibus):                  0.935   Jarque-Bera (JB):                0.203
# Skew:                          -0.166   Prob(JB):                        0.904
# Kurtosis:                       2.581   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Users/bluemishu/venv/lib/python3.10/site-packages/scipy/stats/_axis_nan_policy.py:418: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=17 observations were given.
#   return hypotest_fun_in(*args, **kwds)

# %%
# prediction for new data
regression.predict(scaler.transform([[72]]))
# Out:
# /Users/bluemishu/venv/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[155.97744705]])
